# %% [markdown]
# <a href="https://colab.research.google.com/github/williammcintosh/machine_learning_projects/blob/main/Keras_TF_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keras and TensorFlow Regression
#
# ### Author
#
# Will McIntosh
#
# ### Purpose
#
# This model will cover the basics of data exploration and use of Keras and Tensor flow to predict the cost of a house.
#
# ### Dataset
#
# This is from [the Kings County Kaggle dataset](https://www.kaggle.com/harlfoxem/housesalesprediction?select=kc_house_data.csv).

# %%
#Import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Ignore Matplotlib warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Get the Dataset
df = pd.read_csv('https://drive.google.com/uc?export=download&id=17MBXf_01vmI9iDkBzkF9YcEbvmIQ8RMW')

# %% [markdown]
# ## Data Exploration

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21613.0  4.580302e+09  ...  7.308900e+09  9.900000e+09
# price          21613.0  5.400881e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21613.0  3.370842e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21613.0  2.114757e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21613.0  2.079900e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21613.0  1.510697e+04  ...  1.068800e+04  1.651359e+06
# floors         21613.0  1.494309e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21613.0  7.541757e-03  ...  0.000000e+00  1.000000e+00
# view           21613.0  2.343034e-01  ...  0.000000e+00  4.000000e+00
# condition      21613.0  3.409430e+00  ...  4.000000e+00  5.000000e+00
# grade          21613.0  7.656873e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21613.0  1.788391e+03  ...  2.210000e+03  9.410000e+03
# sqft_basement  21613.0  2.915090e+02  ...  5.600000e+02  4.820000e+03
# yr_built       21613.0  1.971005e+03  ...  1.997000e+03  2.015000e+03
# yr_renovated   21613.0  8.440226e+01  ...  0.000000e+00  2.015000e+03
# zipcode        21613.0  9.807794e+04  ...  9.811800e+04  9.819900e+04
# lat            21613.0  4.756005e+01  ...  4.767800e+01  4.777760e+01
# long           21613.0 -1.222139e+02  ... -1.221250e+02 -1.213150e+02
# sqft_living15  21613.0  1.986552e+03  ...  2.360000e+03  6.210000e+03
# sqft_lot15     21613.0  1.276846e+04  ...  1.008300e+04  8.712000e+05
#
# [20 rows x 8 columns]

# %%
#Removing unhelpful columns
df = df.drop('id', axis=1)

#convert 'date' from string to datetime object
df['date'] = pd.to_datetime(df['date'])

#Extract year and month components
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

#Remove unwanted date column
df = df.drop('date', axis=1)

#There are too many of these to make a dummy variable
df = df.drop('zipcode', axis=1)

# %%
#Examining Price Distribution. It's very right skewed, so we'll need to remove some outliers
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
#Notice here that 'sqft_living' has a strong correlation to price of the house
df.corr()['price'].sort_values()
# Out:
# month           -0.010081
# year             0.003576
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Removing Outliers

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#            price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 7252   7700000.0         6       8.00  ...        8800  2014     10
# 3914   7062500.0         5       4.50  ...       25449  2014      6
# 9254   6885000.0         6       7.75  ...       42730  2014      9
# 4411   5570000.0         5       5.75  ...       24345  2014      8
# 1448   5350000.0         5       5.00  ...       21750  2015      4
# 1315   5300000.0         6       6.00  ...       24619  2015      4
# 1164   5110800.0         5       5.25  ...       26788  2014     10
# 8092   4668000.0         5       6.75  ...       10454  2014      6
# 2626   4500000.0         5       5.50  ...       23408  2014      8
# 8638   4489000.0         4       3.00  ...       14592  2014      6
# 12370  4208000.0         5       6.00  ...       19329  2015      5
# 4149   4000000.0         4       5.50  ...       15996  2014     10
# 2085   3850000.0         4       4.25  ...       22748  2014     11
# 19017  3800000.0         3       4.25  ...       45302  2014      9
# 7035   3800000.0         5       5.50  ...       20570  2014      7
# 16302  3710000.0         4       3.50  ...       19602  2014      5
# 6508   3650000.0         6       4.75  ...       15810  2015      4
# 18482  3650000.0         5       3.75  ...       11275  2015      5
# 15255  3640900.0         4       3.25  ...       25582  2014      9
# 19148  3635000.0         5       6.00  ...       17600  2014     10
#
# [20 rows x 20 columns]

# %%
#Visualizing the correlation of the sqft_living space feature
plt.figure(figsize=(10,5))
sns.scatterplot(x='price',y='sqft_living', data=df)

# %%
#This shows the distribution of prices per bedroom.
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms', y='price', data=df)

# %%
#Drop really expensive outlier houses
len(df)
# Out:
# 21613

# %%
# Get the bottom 99%
ninety_nine_p_df = df.sort_values('price', ascending=False).iloc[216:]

# %% [markdown]
# ## Exploring Lat / Long

# %%
#Examining the latitude and longitude

# %% [markdown]
# ![king_county.jpeg](data:image/jpeg;base64,...)
#
# King County Council has nine members who each represent a district. Courtesy of kingcounty.gov

# %%
#Scatter plotting the longitude and latitude provide a type of map
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat',
                data=ninety_nine_p_df,
                edgecolor=None,
                alpha=0.2,
                hue='price')

# %%
#Those on the waterfront are going to be more expensive
sns.boxplot(x='waterfront',y='price',data=df)

# %% [markdown]
# ## Examining Prices by Date

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)

# %%
#The prices increases in the warmer weather by 50,000
df.groupby('month').mean()['price'].plot()

# %% [markdown]
# ## Train and Test Split
#
# Split the dataframe (100% data) to the test and training data sets.

# %%
#Convert both X and y coordinates as '.values' as Numpy arrays for TensorFlow
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

#Fit and transform in a single step
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train.shape
# Out:
# (15129, 19)

# %%
#Adding the neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

#insert 19 the X_train.shape from above
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

#A single output layer
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

#After each epoch, we will check the test data
#Keras will only use the validation data to update the weights
#Batching since the dataset is large, so we bath it
#Smaller bathces means more time, but less chance of overfitting
#Epochs are the amount of time that TensorFlow will go over the dataset
#Verbose=0 means means no output, since we plot the loss below
model.fit(x=X_train, y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,
          epochs=400,
          verbose=0)

# %% [markdown]
# ## Explore Model History
#
# We look at the history of the model to see its loss decreasing over each epoch.

# %%
#Since we passed in the validation tuple,
#we not only get the loss, but we get the loss on the validation data
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
#After 400 epochs, the validation loss is still going down.
#If we see the values spike up, that is an indicator of overfitting.

# %% [markdown]
# ## Evaluation on Test Data

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score
predictions = model.predict(X_test)
mean_squared_error(y_test, predictions)
# Out:
# 28174238152.747368

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 103279.79444835364

# %%
#This means our estimator is off by roughly 100k dollars.
#Is that good?
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
#Notice here the mean value of a house is 500k, so we're off by 20%.
#That's bad.
5.400881e+05
# Out:
# 540088.1

# %%
#Our accuracy is around 80%
explained_variance_score(y_test, predictions)
# Out:
# 0.7995380810107787

# %%
#The red line represents the perfect prediction line.
#We are being punished by the outlier expensive homes.
plt.figure(figsize=(12,6))
plt.scatter(y_test, predictions)
plt.plot(y_test,y_test, 'r')

# %% [markdown]
# ## Use the Model to Predict on a brandnew House

# %%
#Pick the very first house from the dataframe
single_house = df.drop('price', axis=1).iloc[0]

# %%
#Scale this single house data as a numpy array.
#Reshape it to be a matrix
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
model.predict(single_house)
# Out:
# array([[282322.62]], dtype=float32)

# %%
#The house is worth 221k but estimated to caost 289k.
#A difference of 70k.
df.head(1)
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3        1.0  ...        5650  2014     10
#
# [1 rows x 20 columns]

# %% [markdown]
# ## Retrain on the Bottom 99%

# %%
#Convert both X and y coordinates as '.values' as Numpy arrays for TensorFlow
X = ninety_nine_p_df.drop('price', axis=1).values
y = ninety_nine_p_df['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = MinMaxScaler()

#Fit and transform in a single step
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train.shape
# Out:
# (14977, 19)

# %%
#Adding the neural networks
model = Sequential()

#insert 19 the X_train.shape from above
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

#A single output layer
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.fit(x=X_train, y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,
          epochs=400,
          verbose=0)

# %% [markdown]
# ## Explore Model History on 99%
#
# We look at the history of the model to see its loss decreasing over each epoch.

# %%
#Since we passed in the validation tuple,
#we not only get the loss, but we get the loss on the validation data
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
#After 400 epochs, the validation loss is still going down.
#If we see the values spike up, that is an indicator of overfitting.

# %% [markdown]
# ## Evaluation on Test Data on 99%

# %%
predictions = model.predict(X_test)
mean_squared_error(y_test, predictions)
# Out:
# 21497093375.564915

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 98693.33020529109

# %%
#This means our estimator is off by roughly 100k dollars.
#Is that good?
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
#Notice here the mean value of a house is 500k, so we're off by 20%.
#That's bad.
5.400881e+05
# Out:
# 540088.1

# %%
#Our accuracy is around 80%
explained_variance_score(y_test, predictions)
# Out:
# 0.7382422655069897

# %%
#The red line represents the perfect prediction line.
#We are being punished by the outlier expensive homes.
plt.figure(figsize=(12,6))
plt.scatter(y_test, predictions)
plt.plot(y_test,y_test, 'r')

# %% [markdown]
# ## Use the Model to Predict on a brandnew House

# %%
#Pick the very first house from the dataframe
single_house = df.drop('price', axis=1).iloc[0]

# %%
#Scale this single house data as a numpy array.
#Reshape it to be a matrix
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
model.predict(single_house)
# Out:
# array([[287817.7]], dtype=float32)

# %%
#The house is worth 221k but estimated to cost 270k.
#A difference of 50k.
df.head(1)
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3        1.0  ...        5650  2014     10
#
# [1 rows x 20 columns]
